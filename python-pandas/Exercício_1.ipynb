# %% [markdown]
# # Criação e Manipulação de Series

# %% [markdown]
# ##### Objetivo: Praticar a criação de Series a partir de diferentes estruturas e operações orientadas por índices.
# ##### Crie um dicionário chamado dados_upe contendo 4 disciplinas do seu período atual como chaves e uma nota fictícia (0 a 10) como valor.
# ##### Converta esse dicionário em uma Series do Pandas.
# ##### Crie uma segunda Series com as mesmas disciplinas, mas com notas de um "segundo semestre" fictício.
# ##### Some as duas Series para obter a média aritmética das notas (Dica: some e divida por 2).
# #### Desafio: O que acontece se uma disciplina existir em apenas uma das Series? Comente no código sobre o valor NaN.

# %%
import pandas as pd
import numpy as np

# %%
dados_upe = {'Matematica' : 10, 'Fisica' : 8, 'Ingles' : 7.5, 'Calculo' : 9}

# %%
ser1= pd.Series(dados_upe)
ser1
# Out:
# Matematica    10.0
# Fisica         8.0
# Ingles         7.5
# Calculo        9.0
# dtype: float64

# %%
dados_upe2 = {'Matematica' : 8, 'Fisica' : 6.5, 'Ingles' : 4, 'Calculo' : 10}

# %%
ser2 = pd.Series(dados_upe2)
ser2
# Out:
# Matematica     8.0
# Fisica         6.5
# Ingles         4.0
# Calculo       10.0
# dtype: float64

# %%
(ser1 + ser2)/2
# Out:
# Matematica    9.00
# Fisica        7.25
# Ingles        5.75
# Calculo       9.50
# dtype: float64
